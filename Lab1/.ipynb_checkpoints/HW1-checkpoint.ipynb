# %% [markdown]
# 1) Please plot the noisy data and the polynomial you found (in the same figure). You can use any value of m selected from 2, 3, 4, 5, 6.
#
# I chose m=3

# %%
import matplotlib.pyplot as plt
import matplotlib
plt.style.use('seaborn-whitegrid')
import numpy as np

noise_scale = 100
number_of_samples = 50
x = 25*(np.random.rand(number_of_samples, 1) - 0.8)
y = 5 * x + 20 * x**2 + 1 * x**3 + noise_scale*np.random.randn(number_of_samples, 1)
plt.plot(x,y,'ro', label='Input')

x = x.ravel()
y = y.ravel()
t = np.linspace(-20,5)

trend = np.polyfit(x,y,3)
plt.plot(t, np.polyval(trend, t), label='Trend')

plt.legend()

# %% [markdown]
# 2) Plot MSE versus order m for m = 1, 2, 3, 4, 5, 6, 7, 8. Identify the best choice of order m.
#
# The best order m would be 3

# %%
import matplotlib.pyplot as plt
import matplotlib
plt.style.use('seaborn-whitegrid')
import numpy as np

noise_scale = 100
number_of_samples = 50
x = 25*(np.random.rand(number_of_samples, 1) - 0.8)
y = 5 * x + 20 * x**2 + 1 * x**3 + noise_scale*np.random.randn(number_of_samples, 1)

for i in range(1, 9):
  plt.figure(i)
  plt.plot(x,y,'ro', label='Input')

  x = x.ravel()
  y = y.ravel()
  t = np.linspace(-20,5)

  trend = np.polyfit(x,y,i)
  print(f'm={i}: {trend}')
  plt.plot(t, np.polyval(trend, t), label='Trend')
  plt.title(f'M={i}')
  plt.legend()
# Out:
# m=1: [-29.67307102 342.45691842]
# m=2: [ -2.33766479 -64.49314035 349.96209625]
# m=3: [ 0.95835601 18.97809988  0.86081532 35.71914911]
# m=4: [-9.92888585e-03  6.63929529e-01  1.69591367e+01  3.49042240e+00
#   5.89018318e+01]
# m=5: [ 7.67728361e-04  1.85801718e-02  9.54545711e-01  1.71273416e+01
#  -2.26463903e+00  5.72315104e+01]
# m=6: [ 2.71971445e-04  1.27817326e-02  1.84490674e-01  1.49758378e+00
#   1.38535390e+01 -1.50532086e+01  7.20639596e+01]
# m=7: [-1.43186367e-05 -4.68289607e-04 -1.44826862e-04  1.11263780e-01
#   1.66983428e+00  1.59483425e+01 -1.50258028e+01  6.49515177e+01]
# m=8: [ 6.20872225e-06  3.53884512e-04  7.33415718e-03  6.34662313e-02
#   1.29345961e-01 -2.93233363e-01  1.19628335e+01 -5.69906891e-01
#   7.51116042e+01]

# %% [markdown]
# 3) Change variable noise_scale to 150, 200, 400, 600, 1000 respectively, re-run the algorithm and plot the polynomials with the m found in 2). Discuss the impact of noise scale to the accuracy of the returned parameters. [You need to plot a figure like in 1) for each choice of noise_scale.]
#
# As the noise scale increases, the coefficients of the trendline stray further from the actual coefficients.

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.style.use('seaborn-whitegrid')
import numpy as np

for i in [150, 200, 400, 600, 1000]:
  plt.figure(i)
  number_of_samples = 50
  x = 25*(np.random.rand(number_of_samples, 1) - 0.8)
  y = 5 * x + 20 * x**2 + 1 * x**3 + i*np.random.randn(number_of_samples, 1)
  plt.plot(x,y,'ro', label='Input')

  x = x.ravel()
  y = y.ravel()
  t = np.linspace(-20,5)

  trend = np.polyfit(x,y,3)
  print(f'noise_scale={i}: {trend}')
  plt.plot(t, np.polyval(trend, t), label='Trend')
  plt.title(f'noise_scale={i}')
  plt.legend()
# Out:
# noise_scale=150: [  0.97269086  18.90449439  -3.94513109 -11.91112769]
# noise_scale=200: [ 0.84594727 16.83230035 -4.2072364  14.08434882]
# noise_scale=400: [  0.87647956  16.32844754 -14.58690188  53.87142799]
# noise_scale=600: [   1.26640759   25.69258716    7.42559891 -216.3376793 ]
# noise_scale=1000: [   1.6017789    32.60785982   35.88701474 -120.3768973 ]

# %% [markdown]
# 4) Change variable number_of_samples to 40, 30, 20, 10 respectively, re-ran the algorithm and plot the polynomials with the m found in 2). Discuss the impact of the number of samples to the accuracy of the returned parameters. [You need to plot a figure like in 1) for each choice of number_of_samples.]
#
# The impact of changing the number of samples is relatively limited when compared to introducing more noise. This would mean that it is better to have less data that is better in quality, than more data that is not as good.

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.style.use('seaborn-whitegrid')
import numpy as np

for i in [40, 30, 20, 10]:
  plt.figure(i)
  noise_scale = 100
  x = 25*(np.random.rand(i, 1) - 0.8)
  y = 5 * x + 20 * x**2 + 1 * x**3 + noise_scale*np.random.randn(i, 1)
  plt.plot(x,y,'ro', label='Input')

  x = x.ravel()
  y = y.ravel()
  t = np.linspace(-20,5)

  trend = np.polyfit(x,y,3)
  print(f'number_of_samples={i}: {trend}')
  plt.plot(t, np.polyval(trend, t), label='Trend')
  plt.title(f'number_of_samples={i}')
  plt.legend()
# Out:
# number_of_samples=40: [ 0.97775918 19.50288527  5.80388807  0.22277829]
# number_of_samples=30: [  1.09571988  22.13131056   9.04476694 -64.17593106]
# number_of_samples=20: [  1.31532629  29.04644374  61.8827523  -22.02733589]
# number_of_samples=10: [ 0.91367805 18.92450143 11.88763734 23.6989491 ]
